# %%
# Load the Boston Housing dataset  | Note: Not using Boston Dataset since it's deprecated
# boston = load_boston()

# Load the California Housing dataset
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
housing = fetch_california_housing()

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(housing.data, housing.target, test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be82a844217a> in <cell line: 3>()
#       1 # Standardize the features
#       2 scaler = StandardScaler()
# ----> 3 X_train = scaler.fit_transform(X_train)
#       4 X_test = scaler.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
# Build the model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# %%
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 516/516 [==============================] - 2s 2ms/step - loss: 0.8468
# Epoch 2/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.4098
# Epoch 3/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.4458
# Epoch 4/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3507
# Epoch 5/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3355
# Epoch 6/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3266
# Epoch 7/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3481
# Epoch 8/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3107
# Epoch 9/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3087
# Epoch 10/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2961
# Epoch 11/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.3088
# Epoch 12/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.3026
# Epoch 13/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2980
# Epoch 14/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2838
# Epoch 15/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2856
# Epoch 16/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2812
# Epoch 17/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2900
# Epoch 18/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2786
# Epoch 19/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2701
# Epoch 20/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2719
# Epoch 21/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2697
# Epoch 22/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2674
# Epoch 23/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2699
# Epoch 24/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2668
# Epoch 25/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2645
# Epoch 26/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2616
# Epoch 27/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2591
# Epoch 28/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2590
# Epoch 29/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2580
# Epoch 30/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2558
# Epoch 31/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2560
# Epoch 32/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2517
# Epoch 33/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2504
# Epoch 34/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2516
# Epoch 35/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2500
# Epoch 36/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2510
# Epoch 37/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2468
# Epoch 38/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2476
# Epoch 39/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2447
# Epoch 40/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2447
# Epoch 41/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2436
# Epoch 42/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2412
# Epoch 43/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2402
# Epoch 44/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2391
# Epoch 45/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2370
# Epoch 46/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2402
# Epoch 47/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 48/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2380
# Epoch 49/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2381
# Epoch 50/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2345
# Epoch 51/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2339
# Epoch 52/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2333
# Epoch 53/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2347
# Epoch 54/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2309
# Epoch 55/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2327
# Epoch 56/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2314
# Epoch 57/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2297
# Epoch 58/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2287
# Epoch 59/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2286
# Epoch 60/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2266
# Epoch 61/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2285
# Epoch 62/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2259
# Epoch 63/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2245
# Epoch 64/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2245
# Epoch 65/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2226
# Epoch 66/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2241
# Epoch 67/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2229
# Epoch 68/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2241
# Epoch 69/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2213
# Epoch 70/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2196
# Epoch 71/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2216
# Epoch 72/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2200
# Epoch 73/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2191
# Epoch 74/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2185
# Epoch 75/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2185
# Epoch 76/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2176
# Epoch 77/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2171
# Epoch 78/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2166
# Epoch 79/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2163
# Epoch 80/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2158
# Epoch 81/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2139
# Epoch 82/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2143
# Epoch 83/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2131
# Epoch 84/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2140
# Epoch 85/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2133
# Epoch 86/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2119
# Epoch 87/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2125
# Epoch 88/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2118
# Epoch 89/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2093
# Epoch 90/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2110
# Epoch 91/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2110
# Epoch 92/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2101
# Epoch 93/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2097
# Epoch 94/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2079
# Epoch 95/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2089
# Epoch 96/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2092
# Epoch 97/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2087
# Epoch 98/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2088
# Epoch 99/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2073
# Epoch 100/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2066

# %%
# Evaluate the model
loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Loss: {loss}')
# Out:
# Test Loss: 0.2623990476131439

# %%
# Display sample predictions
for i in range(10):
    print(f'True Price: {y_test[i]}, Predicted Price: {y_pred[i][0]}')
# Out:
# True Price: 0.477, Predicted Price: 0.47630974650382996
# True Price: 0.458, Predicted Price: 1.1919581890106201
# True Price: 5.00001, Predicted Price: 5.1988205909729
# True Price: 2.186, Predicted Price: 2.401042938232422
# True Price: 2.78, Predicted Price: 2.729128837585449
# True Price: 1.587, Predicted Price: 1.5523064136505127
# True Price: 1.982, Predicted Price: 2.314966917037964
# True Price: 1.575, Predicted Price: 1.5092437267303467
# True Price: 3.4, Predicted Price: 2.69204044342041
# True Price: 4.466, Predicted Price: 4.991840362548828

# %%
# Predict on test data
y_pred = model.predict(X_test)
# Out:
# 129/129 [==============================] - 0s 1ms/step
